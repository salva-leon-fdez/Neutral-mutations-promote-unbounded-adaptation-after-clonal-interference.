# %% [markdown]
# # Reproducible Code for: Neutral mutations promote unbounded adaptation after clonal interference.

# %% [markdown]
# ### Salvador León Fernández, Miguel Ángel Fortuna Alcolado.

# %% [markdown]
# Here, we will merge `db_mut_load.csv` with `db_lineages.csv` to extract the main lineage of organisms belonging to the evolutionary lines that survived until the end of the experiment, thus obtaining their abundance data.

# %% [markdown]
# ---

# %% [markdown]
# ## Setup & Environment

# %%
library("tidyverse")
library("data.table")

# %%
db_abundance = fread("../../DATA/db_mut_load.csv")
db_abundance %>% head
db_abundance %>% tail
db_abundance %>% nrow
# Out:
#   founder_id env_id resource mu    rep_id update
# 1 1012       1659   NOT      0.001 1         0
# 2 1012       1659   NOT      0.001 1      1000
# 3 1012       1659   NOT      0.001 1      1000
# 4 1012       1659   NOT      0.001 1      1000
# 5 1012       1659   NOT      0.001 1      1000
# 6 1012       1659   NOT      0.001 1      1000
#   sequence
# 1 qmwuukrmwxqyqruiytjaalgcirofzhipufxpufkswxgathsvjtxkzzgpmpojwqyetaaopwaklmrsjlsazvuviixgjudyjaodjfhx
# 2 qmwuukrmwxqyqruiytjaalgcirofzhipufxpufkswxgathsvjtxkzzgpmpojwqyetaaopwaklmrsjlsazvuviixgjudyjaodjfhx
# 3 qmwuukrmwxqyqruiytjaalgcirofzhipufxpufkswxgathsvjtxkzzgpmpojwqyetaaopwaklmrsjusazvuviixgjudyjaodjfhx
# 4 qmwuukrmwxqyqruxytjaalgcirofzhipufxpufkswxgathsvjtxkzzgpmpojwqyetaaopwaklmrsjlsazvuviixgjudyjaodjfhx
# 5 qmwuukrmwxqyqruiytjaalgcirofzhipufxpufkswxgathsvjtxkzzgpgpojwqyetaaopwaklmrsjlsazvuviixgjudyjaodjfhx
# 6 qmwuukrmwxqyqruiytjaalgcirofzhipufxpufkswxgathsnjtxkzzgpmpojwqyetaaopwaklmrsjlsazvuviixgjudyjaodjfhx
#   abundance
# 1    1
# 2 9926
# 3   18
# 4   12
# 5    9
# 6    4
#   founder_id env_id resource mu    rep_id update
# 1 1108       569    NOT      1e-04 499    500000
# 2 1108       569    NOT      1e-04 499    500000
# 3 1108       569    NOT      1e-04 499    500000
# 4 1108       569    NOT      1e-04 499    500000
# 5 1108       569    NOT      1e-04 499    500000
# 6 1108       569    NOT      1e-04 499    500000
#   sequence
# 1 unmucybqueqywzjbzqcaobevwrchcovsqzvvyptsceahxvsggkzysayvepvefeydxojhgszhdtenukxipgeivlfaputyb
# 2 unmucybqueqywzjbzqcaobevwrchcovsqzvvyptscuahxvsggkzysayvepvefeydxojhgszhdtenukxipgeivlfaputyb
# 3 unmucybqueqywzjbzqcaobevwrchcovsqzvvyptsceahxvsggkzysayvepvefeydxojhgszhdtenukxipgeivxfaputyb
# 4 unmucybqueqywzjbzqcaobevwrchcovsqzvvyptsceahxvsggkzysayvepvefeydxojhgszhdtenkxipgeivlfaputyb
# 5 unmucybqueqywzjbzqcaobevwrchcovsqzvvyptsceahxvsggkzysayvepvefeydxojhgszhdtenukxipgeivlfaptyb
# 6 unmucysbqueqywzjbzqcaobevwrchcovsqzvvyptsceahxvsggkzysayvepvefeydxojhgszhdtenukxipgeivlfaputyb
#   abundance
# 1 9986
# 2    9
# 3    2
# 4    1
# 5    1
# 6    1
# [1] 27803593

# %%
db_lineages = fread("../../DATA/db_lineages.csv")
db_lineages %>% head
db_lineages %>% tail
db_lineages %>% nrow
# Out:
#   ancestor_dist gest_time length exe_length mut_rate founder_id rep_id update
# 1 0             410       100    71         0.01     1012       241       -1
# 2 1             396       100    58         0.01     1012       241      238
# 3 2             317       101    59         0.01     1012       241     5469
# 4 3             283       101    59         0.01     1012       241     7292
# 5 4             283       101    59         0.01     1012       241     8596
# 6 5             283       101    59         0.01     1012       241    10342
#   lineage_id is_main_lineage fitness   relative_fitness mut_type
# 1 4          TRUE            0.0731707 0.00000          ancestor
# 2 4          TRUE            0.0757576 1.03535          sub
# 3 4          TRUE            0.0946372 1.24921          ins
# 4 4          TRUE            0.1060070 1.12014          sub
# 5 4          TRUE            0.1060070 1.00000          sub
# 6 4          TRUE            0.1060070 1.00000          sub
#   sequence
# 1 qmwuukrmwxqyqruiytjaalgcirofzhipufxpufkswxgathsvjtxkzzgpmpojwqyetaaopwaklmrsjlsazvuviixgjudyjaodjfhx
# 2 qmwuukrmwxqyqruiytjaalgcirofzhipuhxpufkswxgathsvjtxkzzgpmpojwqyetaaopwaklmrsjlsazvuviixgjudyjaodjfhx
# 3 qmwuukrmwxqyqruiytjaalgcirofzhipuhxpufkswxgathsvjtxkzzgpmpojwqyetaaopwaklmrsjlsazvuviixvgjudyjaodjfhx
# 4 qmwuukrmwxqyqruiytjaalgcirofzhipuhxpufkswxgathsvjtxkzzgpmpojwqyetaaopwaklmrsjlsazvuvibxvgjudyjaodjfhx
# 5 qmwuukrmwxqyqruiytjaalgcirofzhipuhxpufkswxgathsvjtxkzzgpmpojwqyetaaopwqklmrsjlsazvuvibxvgjudyjaodjfhx
# 6 qmwuukrmwxqyqruiytjaalgcirofzhipuhxpufkswxgathsvjtxkzzgpmpojwqyetaaokwqklmrsjlsazvuvibxvgjudyjaodjfhx
#   ancestor_dist gest_time length exe_length mut_rate founder_id rep_id update
# 1 13               0      103    103        0.001    1439       28     499948
# 2 13            1260      103     52        0.001    1439       28     499999
# 3 13             361      103     52        0.001    1439       28     499910
# 4 13            1183      103     52        0.001    1439       28     499991
# 5 13             361      103     52        0.001    1439       28     493893
# 6 13             361      103     52        0.001    1439       28     499932
#   lineage_id is_main_lineage fitness   relative_fitness mut_type
# 1 19         FALSE           0.0000000 0.000000         sub
# 2 20         FALSE           0.0238095 0.286508         sub
# 3 21         FALSE           0.0831025 1.000000         sub
# 4 22         FALSE           0.0253593 0.305156         sub
# 5 23         FALSE           0.0831025 1.000000         sub
# 6 24         FALSE           0.0831025 1.000000         sub
#   sequence
# 1 osrwulmoljagcjbmytazncqppthbrklzxdecvvnrcuvnbrbivhwwhyerbgusrqjodneudkazscnbppudgxdencnkhdsjblkeyvgganl
# 2 osrwulmoljagcjbmytazncqppthbrklzxdecvvnrcuvybruivhwwhyerbgusrqjodneudkazscnbppudgxdencnkhdsjblkeyvgganl
# 3 osrwulmoljagcjbmytazncqppthbrklzxdecvvnrcuvybrbivhwwhyerbgusrqjodneudkazscnbppudgxdencnkhdsjklkeyvgganl
# 4 osrwulmoljagcjbmytazncqppthbrklzxdecvvnrcuvybibivhwwhyerbgusrqjodneudkazscnbppudgxdencnkhdsjblkeyvgganl
# 5 osrwulmoljagcjbmytazncqppthbrklzxdecvvnrcuvybrbivhwwhyerbgusrqjodneudkazscnbppudgxdxncnkhdsjblkeyvgganl
# 6 osrwulmojjagcjbmytazncqppthbrklzxdecvvnrcuvybrbivhwwhyerbgusrqjodneudkazscnbppudgxdencnkhdsjblkeyvgganl
# [1] 473705

# %% [markdown]
# ## Extract lineage abundance

# %%
# Deduplicate lineages, keeping only the earliest occurrence per sequence 
# to prevent many-to-many joins
db_lineages_prep <- db_lineages %>%
  select(
    founder_id, 
    rep_id, 
    mut_rate,             
    sequence,             
    update_born = update, 
    lineage_id, 
    is_main_lineage,      
    fitness, 
    relative_fitness      
  ) %>%
  arrange(update_born) %>% 
  distinct(founder_id, rep_id, sequence, mut_rate, .keep_all = TRUE)

# Subset abundance data to essential columns for memory efficiency
db_abundance_prep <- db_abundance %>%
  select(
    founder_id, 
    rep_id, 
    mu,                   
    sequence,             
    update_sample = update, 
    abundance
  )

# Merge datasets via primary keys and order chronologically by sampling time
db_final <- db_lineages_prep %>%
  inner_join(
    db_abundance_prep, 
    by = c("founder_id", "rep_id", "sequence", "mut_rate" = "mu")
  ) %>%
  arrange(update_sample)

# %%
db_final <- db_final %>% arrange(founder_id, rep_id, update_sample)
db_final %>% head
db_final %>% tail
db_final %>% nrow
# Out:
#   founder_id rep_id mut_rate
# 1 1012       1      0.001
# 2 1012       1      0.001
# 3 1012       1      0.001
# 4 1012       1      0.001
# 5 1012       1      0.001
# 6 1012       1      0.001
#   sequence
# 1 qmwuukrmwxqyqruiytjaalgcirofzhipufxpufkswxgathsvjtxkzzgpmpojwqyetaaopwaklmrsjlsazvuviixgjudyjaodjfhx
# 2 qmwuukrmwxqyqruiytjaalgcirofzhipufxpufkswxgathsvjtxkzzgpmpojwqyetaaopwaklmrsjlsazvuviixgjudyjaodjfhx
# 3 qmwuukrmwxqyqruiytjaalgcirofzhipufxpufkswxgathsvjtxkzzgpmpojwqyetaaopwaklmrsjlsazvuviixgjudyjaodjfhx
# 4 qmwuukrmwxqyqruiytjaalgcirofzhipufxpufkswxgathsvjtxkzztpmpojwqyetaaopwaklmrsjlsazvuviixgjudyjaodjfhx
# 5 qmwuukrmwxqyqruiytjaalgcirofzhipufxpufkswxgathsvjtxkzzgpmpojwqyetaaopwaklmrsjlsazvuviixgjudyjaodjfhx
# 6 qmwuukrmwxqyqruiytjaalgcirofzhipufxpufkswxgathsvjtxkzztpmpojwqyetaaopwaklmrsjlsazvuviixgjudyjaodjfhx
#   update_born lineage_id is_main_lineage fitness   relative_fitness
# 1   -1        15         TRUE            0.0731707 0
# 2   -1        15         TRUE            0.0731707 0
# 3   -1        15         TRUE            0.0731707 0
# 4 1911        15         TRUE            0.0731707 1
# 5   -1        15         TRUE            0.0731707 0
# 6 1911        15         TRUE            0.0731707 1
#   update_sample abundance
# 1    0             1
# 2 1000          9926
# 3 2000          9721
# 4 2000             2
# 5 3000          9710
# 6 3000            17
#   founder_id rep_id mut_rate
# 1 5642       382    0.01
# 2 5642       382    0.01
# 3 5642       382    0.01
# 4 5642       382    0.01
# 5 5642       382    0.01
# 6 5642       382    0.01
#   sequence
# 1 faxwehdqehdpnfbyyctybjalihajsevfdwcczkkeszwkjfkgpscfaygclmafacbcdhafmbslffnahobhoayzyfauwmiuzvvqvvvghu
# 2 faxwehdqehdpnfbhyctybjalihajsevudmcczkkeszwkjfkgpscfaygclmafacbcdhuftbslffnahvobhoayzyfanwmiuzvvxvvvghu
# 3 faxwehdqeidpnfbyyctybjadihajsfvudmccztkzszwhjfkgpscfaygclmafacbcdhaftbsldfnaqoqbhoayzyfanwmiuzvvxvvvghu
# 4 faxwehdqeidpnfbyyctybjadihajsevudmcczkkexzwhjfkgpscfaygclmafacbchaftbsldfnahobhoayzyfauwmiuzvvxvvvghu
# 5 faxwehdqeidpnfbyyctybjadihajsevudmcczkkexzwhfkgpscfaygclmafacbcdhaftbsldfwahobhoayzyfauwmiuzvvxvvvghu
# 6 faxwehdqehdpnfbyyctybjalihajsevudwcczkkeszwkjfkgpscfaygclmafacbcdhafmbslffgnahobhoayzyfauwmiuzvvxvvvghu
#   update_born lineage_id is_main_lineage fitness   relative_fitness
# 1 500000       94        FALSE           0.0000000 0.000000
# 2 500000      114        FALSE           0.0226757 0.126228
# 3 500000      140        FALSE           0.0226929 0.125567
# 4 500000      141        FALSE           0.0000000 0.000000
# 5 500000      151        FALSE           0.0295858 0.163708
# 6 500000      216        FALSE           0.0226929 0.125567
#   update_sample abundance
# 1 500000        1
# 2 500000        1
# 3 500000        1
# 4 500000        1
# 5 500000        1
# 6 500000        1
# [1] 649007

# %%
write_csv(db_final, file = "../../DATA/db_joined_mut_load_lineages.csv")
