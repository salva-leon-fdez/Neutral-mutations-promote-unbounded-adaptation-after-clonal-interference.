# %% [markdown]
# # Reproducible Code for: Neutral mutations promote unbounded adaptation after clonal interference.

# %% [markdown]
# ### Salvador León Fernández, Miguel Ángel Fortuna Alcolado.

# %% [markdown]
# We are going to reproduce the figures and statistical analyses from the Results and Discussion section: **Strictly neutral epistasis unlocks inaccessible adaptive pathways.**

# %% [markdown]
# ---

# %% [markdown]
# ## Setup & Environment

# %%
library("tidyverse")

# %% [markdown]
# ## Data Loading & Data Preparation

# %%
db_local = read_csv(file = "../../DATA/db_local_peaks.csv")
db_local %>% head(3)
db_local %>% tail(3)
# Out:
# Rows: 345 Columns: 11
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr (2): previous_non_neutral_sequence, conditionally_neutral_sequence
# dbl (9): rep_id, mut_rate, lineage_id, p_beneficial_mut_previous_non_neutral...
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#   rep_id mut_rate lineage_id p_beneficial_mut_previous_non_neutral_sequence
# 1 1      0.010    4710595    0.001165050
# 2 2      0.010    4974493    0.000425532
# 3 3      0.001     417519    0.003168320
#   p_deletereous_mut_previous_non_neutral_sequence
# 1 0.137087
# 2 0.177447
# 3 0.221782
#   p_neutral_mut_previous_non_neutral_sequence
# 1 0.620194
# 2 0.500851
# 3 0.507723
#   p_lethal_mut_previous_non_neutral_sequence
# 1 0.241553
# 2 0.321277
# 3 0.267327
#   gest_time_previous_non_neutral_sequence
# 1 205
# 2 192
# 3 197
#   gest_time_conditionally_neutral_sequence
# 1 204
# 2 191
# 3 196
#   previous_non_neutral_sequence
# 1 dmwuucrdbkwybrubytjamlgccrecphgpufxpufkhwxgarhvvjmxmzaolpalhwqyxtraoyjaklmrbpaeazvvhvibxvvgjedrnaodjxks
# 2 senwdzdjihdeyfbtytyujabihrqpevwcmszfnaskwdjvrwtmrbugcuyfayrfckfaftbyyynctbreueyhaleuedzvxvvgeo
# 3 uudcsdcrqxlzbalafcklweknbhxidevihwnjpbpcbdomtrmbkijskxepwayxltzuebnkzjareruqgcycujybzczvfcdxvvvvgvgqg
#   conditionally_neutral_sequence
# 1 dcwuucrdbkwybrubytjamlgccrecphgpufxpufkhwxgarhvvjmxmzaolpalhwqyxtraoyjaklmrbpaeazvvhvibxvvgjedrnaodjxks
# 2 senwdzdjihaeyfbtytyujabihrqpevwcmszfnaskwdjvrwtmrbugcuyfayrfckfaftbyyynctbreueyhaleuedzvxvvgeo
# 3 eudcsdcrqxlzbalafcklweknbhxidevihwnjpbpcbdomtrmbkijskxepwayxltzuebnkzjareruqgcycujybzczvfcdxvvvvgvgqg
#   rep_id mut_rate lineage_id p_beneficial_mut_previous_non_neutral_sequence
# 1 199    0.010    6051365    0.000860215
# 2 200    0.001     319335    0.007920790
# 3 200    0.010    4097416    0.001212120
#   p_deletereous_mut_previous_non_neutral_sequence
# 1 0.1621510
# 2 0.0839604
# 3 0.0832323
#   p_neutral_mut_previous_non_neutral_sequence
# 1 0.560430
# 2 0.744158
# 3 0.734141
#   p_lethal_mut_previous_non_neutral_sequence
# 1 0.276559
# 2 0.163960
# 3 0.181414
#   gest_time_previous_non_neutral_sequence
# 1 159
# 2 220
# 3 235
#   gest_time_conditionally_neutral_sequence
# 1 158
# 2 219
# 3 234
#   previous_non_neutral_sequence
# 1 fbcmucybquibyzbzecgoaevwrchcjsczvvvtavvdufaxvvvgkztdsapvepveseyxxgjhgszhdweoikxipgeqvlsaputyb
# 2 elwesjcfrcxdaxqhcqfezysbzvncxvuvvvygweclsloqaowzozhucorjyqaymfotobgebohqdvzqdskbhfvucmogoslveciuanpbl
# 3 zlwkbfcfrcdawqhcsjcecyczncxvuvevyvvgmqeloqahwzozntsorjyqaemfotobgebphadvhadskbhfvucmogoslvecijhbwbl
#   conditionally_neutral_sequence
# 1 fbcmucybquibyebzecgoaevwrchcjsczvvvtavvdufaxvvvgkztdsapvepveseyxxgjhgszhdweoikxipgeqvlsaputyb
# 2 elwesjcfrcxdaxqhczfezysbzvncxvuvvvygweclsloqaowzozhucorjyqaymfotobgebohqdvzqdskbhfvucmogoslveciuanpbl
# 3 dlwkbfcfrcdawqhcsjcecyczncxvuvevyvvgmqeloqahwzozntsorjyqaemfotobgebphadvhadskbhfvucmogoslvecijhbwbl

# %% [markdown]
# ---

# %% [markdown]
# ### Fitness peaks analysis

# %%
db_high_mut <- db_local %>% filter(mut_rate == 0.01)
db_low_mut  <- db_local %>% filter(mut_rate == 0.001)

# %%
low_mut_peaks <- db_low_mut %>%
    summarise(pct_trapped = mean(p_beneficial_mut_previous_non_neutral_sequence == 0) * 100)
low_mut_peaks
# Out:
#   pct_trapped
# 1 0

# %%
high_mut_lineages_strict <- db_high_mut %>%
  summarise(pct_trapped = mean(p_beneficial_mut_previous_non_neutral_sequence == 0) * 100)
high_mut_lineages_strict
# Out:
#   pct_trapped
# 1 20.6422

# %% [markdown]
# > **We identified local fitness peaks under the high mutation rate (21 %) but not under the low mutation rate**

# %%
high_mut_experiments <- db_high_mut %>%
  group_by(rep_id) %>%
  summarise(has_peak = any(p_beneficial_mut_previous_non_neutral_sequence == 0)) %>%
  ungroup() %>%
  summarise(pct_experiments_trapped = mean(has_peak) * 100)
high_mut_experiments
# Out:
#   pct_experiments_trapped
# 1 23.07692

# %% [markdown]
# > **Representing 23% of high-mutation-rate experiments**

# %%
high_mut_lineages_relaxed <- db_high_mut %>%
  summarise(pct_trapped = mean(p_beneficial_mut_previous_non_neutral_sequence < 0.001) * 100)
high_mut_lineages_relaxed
# Out:
#   pct_trapped
# 1 63.30275

# %% [markdown]
# > **Relaxing the peak definition reveals that 63% of lineages are functionally trapped due to extreme scarcity of beneficial neighbors (<0.1%).**

# %% [markdown]
# ### Epistatic effects on ancestral background

# %%
# Classify fitness effects by comparing gestation times (lower time = higher fitness)
db_classified <- db_local %>%
  mutate(
    effect_on_ancestor = case_when(
      gest_time_conditionally_neutral_sequence == 0 | is.na(gest_time_conditionally_neutral_sequence) ~ "Lethal",      # Fails to replicate
      gest_time_conditionally_neutral_sequence < gest_time_previous_non_neutral_sequence ~ "Beneficial",  # Faster replication
      gest_time_conditionally_neutral_sequence == gest_time_previous_non_neutral_sequence ~ "Neutral",     # Equal replication
      gest_time_conditionally_neutral_sequence > gest_time_previous_non_neutral_sequence ~ "Deleterious"  # Slower replication
    )
  )

# Calculate outcome percentages for the high mutation rate (0.01)
epistasis_high <- db_classified %>%
  filter(dplyr::near(mut_rate, 0.01)) %>%
  group_by(effect_on_ancestor) %>%
  summarise(count = n(), .groups = "drop") %>%
  mutate(percentage = round((count / sum(count)) * 100, 2))

cat("\n--- High Mutation Rate (0.01) ---\n")
print(epistasis_high)

# Calculate outcome percentages for the low mutation rate (0.001)
epistasis_low <- db_classified %>%
  filter(dplyr::near(mut_rate, 0.001)) %>%
  group_by(effect_on_ancestor) %>%
  summarise(count = n(), .groups = "drop") %>%
  mutate(percentage = round((count / sum(count)) * 100, 2))

cat("\n--- Low Mutation Rate (0.001) ---\n")
print(epistasis_low)
# Out:
# --- High Mutation Rate (0.01) ---
# # A tibble: 4 × 3
#   effect_on_ancestor count percentage
#   <chr>              <int>      <dbl>
# 1 Beneficial           160      73.4
# 2 Deleterious           13       5.96
# 3 Lethal                24      11.0
# 4 Neutral               21       9.63
#
# --- Low Mutation Rate (0.001) ---
# # A tibble: 2 × 3
#   effect_on_ancestor count percentage
#   <chr>              <int>      <dbl>
# 1 Beneficial           124      97.6
# 2 Neutral                3       2.36

# %% [markdown]
# > **the fitness effect of the final beneficial mutation changed in 27% of cases (becoming lethal in 11% of cases, neutral in 10%, and deleterious in 6%).**

# %% [markdown]
# ---

# %% [markdown]
# ## Reproducibility Session Info

# %%
sessionInfo()
# Out:
# R version 4.2.1 (2022-06-23)
# Platform: x86_64-pc-linux-gnu (64-bit)
# Running under: Ubuntu 20.04.5 LTS
#
# Matrix products: default
# BLAS:   /usr/lib/x86_64-linux-gnu/openblas-pthread/libblas.so.3
# LAPACK: /usr/lib/x86_64-linux-gnu/openblas-pthread/liblapack.so.3
#
# locale:
#  [1] LC_CTYPE=en_US.UTF-8       LC_NUMERIC=C
#  [3] LC_TIME=en_US.UTF-8        LC_COLLATE=en_US.UTF-8
#  [5] LC_MONETARY=en_US.UTF-8    LC_MESSAGES=en_US.UTF-8
#  [7] LC_PAPER=en_US.UTF-8       LC_NAME=C
#  [9] LC_ADDRESS=C               LC_TELEPHONE=C
# [11] LC_MEASUREMENT=en_US.UTF-8 LC_IDENTIFICATION=C
#
# attached base packages:
# [1] stats     graphics  grDevices utils     datasets  methods   base
#
# other attached packages:
#  [1] lubridate_1.9.4 forcats_1.0.0   stringr_1.5.1   dplyr_1.1.4
#  [5] purrr_1.0.4     readr_2.1.5     tidyr_1.3.1     tibble_3.2.1
#  [9] ggplot2_3.5.2   tidyverse_2.0.0
#
# loaded via a namespace (and not attached):
#  [1] pillar_1.10.1     compiler_4.2.1    base64enc_0.1-3   tools_4.2.1
#  [5] bit_4.6.0         digest_0.6.37     uuid_1.2-1        timechange_0.3.0
#  [9] jsonlite_1.9.1    evaluate_1.0.3    lifecycle_1.0.4   gtable_0.3.6
# [13] pkgconfig_2.0.3   rlang_1.1.5       IRdisplay_1.1     cli_3.6.4
# [17] parallel_4.2.1    IRkernel_1.3.2    fastmap_1.2.0     repr_1.1.7
# [21] withr_3.0.2       generics_0.1.3    vctrs_0.6.5       hms_1.1.3
# [25] bit64_4.6.0-1     grid_4.2.1        tidyselect_1.2.1  glue_1.8.0
# [29] R6_2.6.1          vroom_1.6.5       pbdZMQ_0.3-13     tzdb_0.4.0
# [33] magrittr_2.0.3    scales_1.3.0      htmltools_0.5.8.1 colorspace_2.1-1
# [37] utf8_1.2.4        stringi_1.8.4     munsell_0.5.1     crayon_1.5.3

# %% [markdown]
# ---
# ---
